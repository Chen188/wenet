# %% [markdown]
# ## 创建conda环境

# %%
# !conda create -y -n wenet python=3.8
# !source activate wenet

# %% [markdown]
# ## 切换到wenet环境

# %%
# !pip install -r requirements.txt
# !conda install -y pytorch==1.6.0 cudatoolkit=10.1 torchaudio=0.6.0 -c pytorch

# %%
# !conda install -yc conda-forge jupyterlab
# !conda install -yc conda-forge nb_conda_kernels
# Out:
# ...
# Solving environment: -
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - conda-forge/noarch::s3transfer==0.4.2=pyhd8ed1ab_0
#   - conda-forge/noarch::hdijupyterutils==0.18.0=pyh44b312d_0
#   - conda-forge/noarch::botocore==1.20.76=pyhd8ed1ab_0
#   - conda-forge/noarch::sparkmagic==0.18.0=pyhd8ed1ab_0
#   - conda-forge/linux-64::requests-kerberos==0.12.0=py36h5fab9bb_2
#   - conda-forge/linux-64::aiohttp==3.7.4=py36h8f6f2f9_0
#   - conda-forge/noarch::s3fs==2021.5.0=pyhd8ed1ab_0
#   - defaults/noarch::aiobotocore==1.2.2=pyhd3eb1b0_0
#   - conda-forge/linux-64::yarl==1.6.3=py36h8f6f2f9_1
#   - conda-forge/noarch::urllib3==1.26.4=pyhd8ed1ab_0
#   - conda-forge/noarch::boto3==1.17.76=pyhd8ed1ab_0
#   - conda-forge/noarch::autovizwidget==0.18.0=pyh44b312d_0
#   - conda-forge/linux-64::idna_ssl==1.1.0=py36h9f0ad1d_1001
# -
# ...

# %%
# !conda install -yc conda-forge jupyter_contrib_nbextensions

# %%
# !python --version 
# !conda env list
# Out:
# Python 3.6.13
# # conda environments:
# #
# base                     /home/ec2-user/anaconda3
# JupyterSystemEnv      *  /home/ec2-user/anaconda3/envs/JupyterSystemEnv
# R                        /home/ec2-user/anaconda3/envs/R
# amazonei_mxnet_p27       /home/ec2-user/anaconda3/envs/amazonei_mxnet_p27
# amazonei_mxnet_p36       /home/ec2-user/anaconda3/envs/amazonei_mxnet_p36
# amazonei_pytorch_latest_p36     /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p36
# amazonei_tensorflow2_p27     /home/ec2-user/anaconda3/envs/amazonei_tensorflow2_p27
# amazonei_tensorflow2_p36     /home/ec2-user/anaconda3/envs/amazonei_tensorflow2_p36
# amazonei_tensorflow_p27     /home/ec2-user/anaconda3/envs/amazonei_tensorflow_p27
# amazonei_tensorflow_p36     /home/ec2-user/anaconda3/envs/amazonei_tensorflow_p36
# chainer_p27              /home/ec2-user/anaconda3/envs/chainer_p27
# chainer_p36              /home/ec2-user/anaconda3/envs/chainer_p36
# ...

# %%
proj_base_dir='/fsx/wenet/'
# %cd $proj_base_dir

# !pip install -r requirements.txt
# !conda install -y pytorch==1.6.0 cudatoolkit=10.1 torchaudio=0.6.0 -c pytorch

# %%
# !python --version
# Out:
# Python 3.6.13

# %%
# %cd $proj_base_dir/examples/aishell/s0

stage=-1
stop_stage=3

# !bash ./run.sh --stage $stage --stop_stage $stop_stage
# Out:
# /fsx/wenet/examples/aishell/s0
# + . ./path.sh
# ++ export WENET_DIR=/fsx/wenet/examples/aishell/s0/../../..
# ++ WENET_DIR=/fsx/wenet/examples/aishell/s0/../../..
# ++ export BUILD_DIR=/fsx/wenet/examples/aishell/s0/../../../runtime/server/x86/build
# ++ BUILD_DIR=/fsx/wenet/examples/aishell/s0/../../../runtime/server/x86/build
# ++ export OPENFST_PREFIX_DIR=/fsx/wenet/examples/aishell/s0/../../../runtime/server/x86/build/../fc_base/openfst-subbuild/openfst-populate-prefix
# ++ OPENFST_PREFIX_DIR=/fsx/wenet/examples/aishell/s0/../../../runtime/server/x86/build/../fc_base/openfst-subbuild/openfst-populate-prefix
# ...

# %%
stage=4
stop_stage=4
# !bash ./run.sh --stage $stage --stop_stage $stop_stage
# Out:
# + . ./path.sh
# ++ export WENET_DIR=/fsx/wenet/examples/aishell/s0/../../..
# ++ WENET_DIR=/fsx/wenet/examples/aishell/s0/../../..
# ++ export BUILD_DIR=/fsx/wenet/examples/aishell/s0/../../../runtime/server/x86/build
# ++ BUILD_DIR=/fsx/wenet/examples/aishell/s0/../../../runtime/server/x86/build
# ++ export OPENFST_PREFIX_DIR=/fsx/wenet/examples/aishell/s0/../../../runtime/server/x86/build/../fc_base/openfst-subbuild/openfst-populate-prefix
# ++ OPENFST_PREFIX_DIR=/fsx/wenet/examples/aishell/s0/../../../runtime/server/x86/build/../fc_base/openfst-subbuild/openfst-populate-prefix
# ...

# %%
# !python --version
# Out:
# Python 3.6.13
